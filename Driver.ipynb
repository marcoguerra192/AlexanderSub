# %% [markdown]
# # Minimal working example for Alexander duality

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
from itertools import combinations
import networkx as nx

from gudhi import AlphaComplex as AC
# Out:
# /home/marco/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# #### Abstract subdivision

# %%
from Alexander_subdivision import AbstractSubdivision

Subs = {i: AbstractSubdivision(i) for i in range(2,5)}

from Alexander_subdivision import RelAbsSub

# %% [markdown]
# #### Subdivision functions

# %%
from Alexander_subdivision import subdivision, RelSub, tightSupp

# %% [markdown]
# #### Alpha Complex builder

# %%
from Alexander_subdivision import AlphaComplex, getAlphaComplex

# %% [markdown]
# #### Plotting

# %%
from Alexander_subdivision import draw_2d_simplicial_complex, draw_Sup

# %%
# Simple square with center
points = np.array([
    [0,0],
    [1,0],
    [1,1],
    [0,1],
    [0.5,0.5]
])

# %%
M = getAlphaComplex(points, thresh=1.0)

# %%
M
# Out:
# [[0, 1, 4],
#  [1, 2, 4],
#  [0, 3, 4],
#  [2, 3, 4],
#  [0, 4],
#  [1, 4],
#  [2, 4],
#  [3, 4],
#  [0, 1],
#  [1, 2],
#  [0, 3],
#  [2, 3]]

# %%
draw_2d_simplicial_complex(M, pos=points)

# %%
# Choose L as boundary edges
L = [
    [0,1],
    [1,2],
    [2,3],
    [3,0]
]

pointsL = points.copy()

# %%
draw_2d_simplicial_complex(L,pos = pointsL)

# %%
# Compute tight supplement
Lbar, subIndices = tightSupp(L, pointsL, M, points)

# %%
draw_Sup(
